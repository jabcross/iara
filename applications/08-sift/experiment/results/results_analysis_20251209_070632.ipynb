# %% [markdown]
# # 08-sift Experiment Results Analysis
#
# Generated: 2025-12-09 07:06:32
#
# Results file: `results_20251209_070632.csv`
#
# Visualization configuration: `experiments.yaml`

# %%
import sys
import pandas as pd

# Add framework path for visualization module
sys.path.insert(0, '/scratch/pedro.ciambra/repos/iara/applications/experiment-framework')
from visualization_declarative import generate_visualizations_from_yaml
from visualization import print_statistics

csv_file = '/scratch/pedro.ciambra/repos/iara/applications/08-sift/experiment/results/results_20251209_070632.csv'
yaml_file = '/scratch/pedro.ciambra/repos/iara/applications/08-sift/experiment/experiments.yaml'
scheduler_order = ['vf-omp', 'vf-enkits']
results = pd.read_csv(csv_file)
print(f'Loaded {{len(results)}} measurements from {{csv_file}}')
print(f'Schedulers: {{sorted(results["scheduler"].unique()) if "scheduler" in results.columns else []}}')
print(f'Parameters: {{sorted(set(results.columns) - {{"test_name", "measurement", "value", "unit", "run_num", "scheduler"}})}}')
# Out:
# Loaded {len(results)} measurements from {csv_file}
# Schedulers: {sorted(results["scheduler"].unique()) if "scheduler" in results.columns else []}
# Parameters: {sorted(set(results.columns) - {"test_name", "measurement", "value", "unit", "run_num", "scheduler"})}

# %% [markdown]
# ## Data Summary
#
# - **Total measurements**: 64
# - **Schedulers**: vf-enkits, vf-omp
# - **Measurement types**: binary_compilation_time, compute_time, max_rss_mb, section_size
# - **matrix_size**:
# - **num_blocks**:

# %% [markdown]
# ## Interactive Visualizations

# %%
generate_visualizations_from_yaml(csv_file, yaml_file, scheduler_order)
# Out:
# Loaded 64 measurements
# Generating 1 visualization(s) from YAML...
#
# Generating "wall_time": SIFT Runtime Wall Time
#   Skipped: Metric "wall_time" not found in data

# %% [markdown]
# ## Performance Statistics

# %%
print_statistics(results, scheduler_order)
# Out:
# === Compute Time Statistics (ordered by scheduler definition) ===
#            mean  std  min  max  count
# scheduler
# vf-omp      0.0  NaN  0.0  0.0      1
# vf-enkits   0.0  NaN  0.0  0.0      1
#
# === Speedup vs Sequential ===
# vf-omp          :   0.00x
# vf-enkits       :   0.00x

# %% [markdown]
# ## Raw Data
#
# Display first 20 measurement rows

# %%
results.head(20)
# Out:
#                                       test_name  scheduler  matrix_size  \
# 0   08-sift_regression_vf-enkits_image_size_512  vf-enkits          NaN
# 1   08-sift_regression_vf-enkits_image_size_512  vf-enkits          NaN
# 2      08-sift_regression_vf-omp_image_size_512     vf-omp          NaN
# 3      08-sift_regression_vf-omp_image_size_512     vf-omp          NaN
# 4   08-sift_regression_vf-enkits_image_size_512  vf-enkits          NaN
# 5   08-sift_regression_vf-enkits_image_size_512  vf-enkits          NaN
# 6   08-sift_regression_vf-enkits_image_size_512  vf-enkits          NaN
# 7   08-sift_regression_vf-enkits_image_size_512  vf-enkits          NaN
# 8   08-sift_regression_vf-enkits_image_size_512  vf-enkits          NaN
# 9   08-sift_regression_vf-enkits_image_size_512  vf-enkits          NaN
# 10  08-sift_regression_vf-enkits_image_size_512  vf-enkits          NaN
# 11  08-sift_regression_vf-enkits_image_size_512  vf-enkits          NaN
# 12  08-sift_regression_vf-enkits_image_size_512  vf-enkits          NaN
# 13  08-sift_regression_vf-enkits_image_size_512  vf-enkits          NaN
# 14  08-sift_regression_vf-enkits_image_size_512  vf-enkits          NaN
# 15  08-sift_regression_vf-enkits_image_size_512  vf-enkits          NaN
# 16  08-sift_regression_vf-enkits_image_size_512  vf-enkits          NaN
# 17  08-sift_regression_vf-enkits_image_size_512  vf-enkits          NaN
# 18  08-sift_regression_vf-enkits_image_size_512  vf-enkits          NaN
# 19  08-sift_regression_vf-enkits_image_size_512  vf-enkits          NaN
#
#     num_blocks   measurement         section   value   unit
# 0          NaN  compute_time             NaN    0.00      s
# 1          NaN    max_rss_mb             NaN    4.75     MB
# 2          NaN  compute_time             NaN    0.00      s
# 3          NaN    max_rss_mb             NaN    4.75     MB
# 4          NaN  section_size         .interp   28.00  bytes
# 5          NaN  section_size   .note.ABI-tag   32.00  bytes
# 6          NaN  section_size         .dynsym  312.00  bytes
# 7          NaN  section_size    .gnu.version   26.00  bytes
# 8          NaN  section_size  .gnu.version_r   96.00  bytes
# 9          NaN  section_size       .gnu.hash   28.00  bytes
# 10         NaN  section_size         .dynstr  560.00  bytes
# 11         NaN  section_size       .rela.dyn  264.00  bytes
# 12         NaN  section_size       .rela.plt  168.00  bytes
# 13         NaN  section_size         .rodata  181.00  bytes
# 14         NaN  section_size   .eh_frame_hdr   68.00  bytes
# 15         NaN  section_size       .eh_frame  192.00  bytes
# 16         NaN  section_size           .text  654.00  bytes
# 17         NaN  section_size           .init   27.00  bytes
# 18         NaN  section_size           .fini   13.00  bytes
# 19         NaN  section_size            .plt  128.00  bytes
